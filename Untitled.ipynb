# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.seterr(divide='ignore', invalid='ignore')
import seaborn as sns

# %%
data=pd.read_csv("cardio_train.csv",sep=";",index_col="id")

# %%
data.head(10)
# Out:
#       age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 0   18393       2     168    62.0    110     80            1     1      0
# 1   20228       1     156    85.0    140     90            3     1      0
# 2   18857       1     165    64.0    130     70            3     1      0
# 3   17623       2     169    82.0    150    100            1     1      0
# 4   17474       1     156    56.0    100     60            1     1      0
# 8   21914       1     151    67.0    120     80            2     2      0
# 9   22113       1     157    93.0    130     80            3     1      0
# 12  22584       2     178    95.0    130     90            3     3      0
# 13  17668       1     158    71.0    110     70            1     1      0
# 14  19834       1     164    68.0    110     60            1     1      0
#
#     alco  active  cardio
# id
# 0      0       1       0
# 1      0       1       1
# 2      0       0       1
# 3      0       1       1
# 4      0       0       0
# 8      0       0       0
# 9      0       1       0
# 12     0       1       1
# 13     0       1       0
# 14     0       0       0

# %%
data.size
# Out:
# 840000

# %%
data.shape
# Out:
# (70000, 12)

# %%
data.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70000 entries, 0 to 99999
# Data columns (total 12 columns):
# age            70000 non-null int64
# gender         70000 non-null int64
# height         70000 non-null int64
# weight         70000 non-null float64
# ap_hi          70000 non-null int64
# ap_lo          70000 non-null int64
# cholesterol    70000 non-null int64
# gluc           70000 non-null int64
# smoke          70000 non-null int64
# alco           70000 non-null int64
# active         70000 non-null int64
# cardio         70000 non-null int64
# dtypes: float64(1), int64(11)
# memory usage: 6.9 MB

# %%
data["age"]=data["age"].apply(lambda x:x/365)

# %%
data["age"]=data["age"].apply(lambda x: round(x))

# %%
data["height"]=data["height"].apply(lambda x:round(x/100,2))

# %%
data["height"].head(10)
# Out:
# id
# 0     1.68
# 1     1.56
# 2     1.65
# 3     1.69
# 4     1.56
# 8     1.51
# 9     1.57
# 12    1.78
# 13    1.58
# 14    1.64
# Name: height, dtype: float64

# %%
#data["age"]

# %%
data.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.338686      1.349571      1.643592     74.205690    128.817286
# std        6.765294      0.476838      0.082101     14.395757    154.011419
# min       30.000000      1.000000      0.550000     10.000000   -150.000000
# 25%       48.000000      1.000000      1.590000     65.000000    120.000000
# 50%       54.000000      1.000000      1.650000     72.000000    120.000000
# 75%       58.000000      2.000000      1.700000     82.000000    140.000000
# max       65.000000      2.000000      2.500000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# std      188.472530      0.680250      0.572270      0.283484      0.225568
# min      -70.000000      1.000000      1.000000      0.000000      0.000000
# 25%       80.000000      1.000000      1.000000      0.000000      0.000000
# 50%       80.000000      1.000000      1.000000      0.000000      0.000000
# 75%       90.000000      2.000000      1.000000      0.000000      0.000000
# max    11000.000000      3.000000      3.000000      1.000000      1.000000
#
#              active        cardio
# count  70000.000000  70000.000000
# mean       0.803729      0.499700
# std        0.397179      0.500003
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      0.000000
# 75%        1.000000      1.000000
# max        1.000000      1.000000

# %%
data[(data["ap_hi"]<40) | (data["ap_lo"]<40)].groupby(["cardio"]).count()
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# cardio
# 0       126     126     126     126    126    126          126   126    126
# 1       116     116     116     116    116    116          116   116    116
#
#         alco  active
# cardio
# 0        126     126
# 1        116     116

# %%
data[(data["ap_hi"]<40)].groupby(["cardio"]).count()
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# cardio
# 0        94      94      94      94     94     94           94    94     94
# 1        94      94      94      94     94     94           94    94     94
#
#         alco  active
# cardio
# 0         94      94
# 1         94      94

# %%
data[(data["ap_lo"]<40)].groupby(["cardio"]).count()
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# cardio
# 0        34      34      34      34     34     34           34    34     34
# 1        25      25      25      25     25     25           25    25     25
#
#         alco  active
# cardio
# 0         34      34
# 1         25      25

# %%
data=data[data.ap_lo>=40] #remove data that un reasonable

# %%
data=data[data.ap_hi>=40]

# %%
data.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  69758.000000  69758.000000  69758.000000  69758.000000  69758.000000
# mean      53.340778      1.349566      1.643609     74.211636    129.077511
# std        6.764610      0.476836      0.081918     14.397736    153.979751
# min       30.000000      1.000000      0.550000     10.000000     60.000000
# 25%       48.000000      1.000000      1.590000     65.000000    120.000000
# 50%       54.000000      1.000000      1.650000     72.000000    120.000000
# 75%       58.000000      2.000000      1.700000     82.000000    140.000000
# max       65.000000      2.000000      2.500000    200.000000  16020.000000
#
#               ap_lo  cholesterol          gluc         smoke          alco  \
# count  69758.000000  69758.00000  69758.000000  69758.000000  69758.000000
# mean      96.691061      1.36727      1.226669      0.088277      0.053829
# std      188.581826      0.68060      0.572508      0.283699      0.225681
# min       40.000000      1.00000      1.000000      0.000000      0.000000
# 25%       80.000000      1.00000      1.000000      0.000000      0.000000
# 50%       80.000000      1.00000      1.000000      0.000000      0.000000
# 75%       90.000000      2.00000      1.000000      0.000000      0.000000
# max    11000.000000      3.00000      3.000000      1.000000      1.000000
#
#              active        cardio
# count  69758.000000  69758.000000
# mean       0.803793      0.499771
# std        0.397130      0.500004
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      0.000000
# 75%        1.000000      1.000000
# max        1.000000      1.000000

# %%
#sns.catplot(x="age", y="cardio",
#            kind="bar", data=data);

# %%
sns.set()

# %%
sns.boxplot(x='cardio',y='age',data=data)

# %%
sns.distplot(data['age'])

# %%
sns.boxplot(x='cardio',y='weight',data=data)

# %%
sns.distplot(data['weight'])

# %%
data[data['weight']>100].groupby(["cardio"]).count()
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# cardio
# 0        999     999     999     999    999    999          999   999    999
# 1       2244    2244    2244    2244   2244   2244         2244  2244   2244
#
#         alco  active
# cardio
# 0        999     999
# 1       2244    2244

# %%
data[data['weight']<50].groupby(["cardio"]).count()
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# cardio
# 0       712     712     712     712    712    712          712   712    712
# 1       272     272     272     272    272    272          272   272    272
#
#         alco  active
# cardio
# 0        712     712
# 1        272     272

# %%
sns.boxplot(x='cardio',y='height',data=data)

# %%
data[data['ap_hi']>200].groupby(["cardio"]).count()
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# cardio
# 0        19      19      19      19     19     19           19    19     19
# 1        74      74      74      74     74     74           74    74     74
#
#         alco  active
# cardio
# 0         19      19
# 1         74      74

# %%
data=data[data['ap_hi']<=200]

# %%
sns.boxplot(x='cardio',y='ap_hi',data=data)

# %%
sns.distplot(data['ap_hi'])

# %%
data=data[data['ap_lo']<200]

# %%
sns.boxplot(x='cardio',y='ap_lo',data=data)

# %%
def rstr(df, pred=None): 
    obs = df.shape[0]
    types = df.dtypes
    counts = df.apply(lambda x: x.count())
    uniques = df.apply(lambda x: [x.unique()])
    nulls = df.apply(lambda x: x.isnull().sum())
    distincts = df.apply(lambda x: x.unique().shape[0])
    missing_ration = (df.isnull().sum()/ obs) * 100
    skewness = df.skew()
    kurtosis = df.kurt() 
    print('Data shape:', df.shape)
    
    if pred is None:
        cols = ['types', 'counts', 'distincts', 'nulls', 'missing ration', 'uniques', 'skewness', 'kurtosis']
        str = pd.concat([types, counts, distincts, nulls, missing_ration, uniques, skewness, kurtosis], axis = 1)

    else:
        corr = df.corr()[pred]
        str = pd.concat([types, counts, distincts, nulls, missing_ration, uniques, skewness, kurtosis, corr], axis = 1, sort=False)
        corr_col = 'corr '  + pred
        cols = ['types', 'counts', 'distincts', 'nulls', 'missing_ration', 'uniques', 'skewness', 'kurtosis', corr_col ]
    
    str.columns = cols
    dtypes = str.types.value_counts()
    print('___________________________\nData types:\n',str.types.value_counts())
    print('___________________________')
    return str

# %%
rstr(data, "cardio").sort_values(by='corr cardio', ascending=False)
# Out:
# Data shape: (68723, 12)
# ___________________________
# Data types:
#  int64      10
# float64     2
# Name: types, dtype: int64
# ___________________________
#                types  counts  distincts  nulls  missing_ration  \
# cardio         int64   68723          2      0             0.0
# ap_hi          int64   68723        102      0             0.0
# ap_lo          int64   68723         84      0             0.0
# age            int64   68723         28      0             0.0
# cholesterol    int64   68723          3      0             0.0
# weight       float64   68723        281      0             0.0
# gluc           int64   68723          3      0             0.0
# gender         int64   68723          2      0             0.0
# alco           int64   68723          2      0             0.0
# height       float64   68723        106      0             0.0
# smoke          int64   68723          2      0             0.0
# active         int64   68723          2      0             0.0
#
#                                                        uniques  skewness  \
# cardio                                            [[0.0, 1.0]]  0.021334
# ap_hi        [[110.0, 140.0, 130.0, 150.0, 100.0, 120.0, 14...  0.818693
# ap_lo        [[80.0, 90.0, 70.0, 100.0, 60.0, 85.0, 89.0, 1...  0.613012
# age          [[50.0, 55.0, 52.0, 48.0, 60.0, 61.0, 62.0, 54... -0.304830
# cholesterol                                  [[1.0, 3.0, 2.0]]  1.597701
# weight       [[62.0, 85.0, 64.0, 82.0, 56.0, 67.0, 93.0, 95...  1.007251
# gluc                                         [[1.0, 2.0, 3.0]]  2.402241
# gender                                            [[2.0, 1.0]]  0.635568
# alco                                              [[0.0, 1.0]]  3.963172
# height       [[1.68, 1.56, 1.65, 1.69, 1.51, 1.57, 1.78, 1.... -0.608854
# smoke                                             [[0.0, 1.0]]  2.908893
# active                                            [[1.0, 0.0]] -1.526615
#
#               kurtosis  corr cardio
# cardio       -1.999603     1.000000
# ap_hi         1.327372     0.427550
# ap_lo         4.068199     0.335297
# age          -0.823974     0.239139
# cholesterol   1.028023     0.221425
# weight        2.560414     0.179681
# gluc          4.315985     0.089963
# gender       -1.596099     0.006978
# alco         13.707133    -0.008378
# height        7.591305    -0.010918
# smoke         6.461847    -0.016464
# active        0.330563    -0.037241

# %%
sns.pairplot(data=data, hue="cardio")

# %%
plt.figure(6)
fig, ax = plt.subplots(figsize=(50, 20))
corr = data.corr()
sns.set(font_scale=1.25)
sns.heatmap(round(corr,3),linewidths=0.1,vmax=1.0, 
            square=True,linecolor='white', annot=True)

# %%
sns.countplot(x='cardio',data=data,hue='gender',palette='winter')

# %%
sns.countplot(x='cardio',data=data,hue='smoke',palette='winter')

# %%
data["cardio"].value_counts().plot(kind='pie', subplots=True, figsize=(8, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a55294710>],
#       dtype=object)

# %%
data["alco"].value_counts().plot(kind='pie', subplots=True, figsize=(8, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a50b90080>],
#       dtype=object)

# %%
data["gender"].value_counts().plot(kind='pie', subplots=True, figsize=(8, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a4d89fa20>],
#       dtype=object)

# %%
data["active"].value_counts().plot(kind='pie', subplots=True, figsize=(8, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a4d8dd390>],
#       dtype=object)

# %%
data["cholesterol"].value_counts().plot(kind='pie', subplots=True, figsize=(8, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a55cc7cf8>],
#       dtype=object)

# %%
data["gluc"].value_counts().plot(kind='pie', subplots=True, figsize=(8, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a4667b9e8>],
#       dtype=object)

# %%
ax = sns.scatterplot(x="gender", y="height",hue='cardio', data=data)

# %%
sns.distplot(data['ap_lo'])

# %%
sns.distplot(data['height'])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
data.to_csv('data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e3f035d75a89> in <module>
# ----> 1 data.to_csv('data')
#
# NameError: name 'data' is not defined

# %%
data_copy=data.copy()

y=data['cardio'].copy()

# %%
X=data_copy.drop("cardio", axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pred = regressor.predict(x_test)

# %%
# The coefficients
print('Coefficients: \n', regressor.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % metrics.mean_squared_error(y_test, pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % metrics.r2_score(y_test, pred))
# Out:
# Coefficients:
#  [ 0.01009532 -0.00307017 -0.06639967  0.00196903  0.00963454  0.0030567
#   0.09887908 -0.01993367 -0.02996458 -0.04221516 -0.04532759]
# Mean squared error: 0.19
# Variance score: 0.23

# %%
print('Training Features Shape:', x_train.shape)
print('Training Labels Shape:', y_train.shape)
print('Testing Features Shape:', x_test.shape)
print('Testing Labels Shape:', y_test.shape)
# Out:
# Training Features Shape: (51542, 11)
# Training Labels Shape: (51542,)
# Testing Features Shape: (17181, 11)
# Testing Labels Shape: (17181,)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# Mean Absolute Error: 0.3915871463239686
# Mean Squared Error: 0.19171985840959965
# Root Mean Squared Error: 0.4378582629226034

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(random_state=0, solver='sag', multi_class='ovr').fit(x_train, y_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %%
ypredict=clf.predict(x_test)

# %%
clf.score(x_train, y_train)
# Out:
# 0.7182879981374413

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, ypredict))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, ypredict))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, ypredict)))
# Out:
# Mean Absolute Error: 0.28013503288516384
# Mean Squared Error: 0.28013503288516384
# Root Mean Squared Error: 0.5292778409164357
